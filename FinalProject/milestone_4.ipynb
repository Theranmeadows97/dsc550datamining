# %% [markdown]
# # Milestone 4

# %% [markdown]
# #### Getting the final data set

# %%
import pandas as pd

# %%
prostate_data = pd.read_csv("/Users/theranmeadows/Desktop/dsc550datamining/FinalProject/Prostate_Cancer.csv")
prostate_data.head()
# Out:
#    id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0   1                M      23       12        151   954       0.143
# 1   2                B       9       13        133  1326       0.143
# 2   3                M      21       27        130  1203       0.125
# 3   4                M      14       16         78   386       0.070
# 4   5                M       9       19        135  1297       0.141
#
#    compactness  symmetry  fractal_dimension
# 0        0.278     0.242              0.079
# 1        0.079     0.181              0.057
# 2        0.160     0.207              0.060
# 3        0.284     0.260              0.097
# 4        0.133     0.181              0.059

# %%
prostate_data = prostate_data.replace("M", 1)
prostate_data = prostate_data.replace("B", 0)
prostate_data.head()
# Out:
#    id  diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0   1                 1      23       12        151   954       0.143
# 1   2                 0       9       13        133  1326       0.143
# 2   3                 1      21       27        130  1203       0.125
# 3   4                 1      14       16         78   386       0.070
# 4   5                 1       9       19        135  1297       0.141
#
#    compactness  symmetry  fractal_dimension
# 0        0.278     0.242              0.079
# 1        0.079     0.181              0.057
# 2        0.160     0.207              0.060
# 3        0.284     0.260              0.097
# 4        0.133     0.181              0.059

# %% [markdown]
# #### Split the data into training and test sets with the target variable being 'diagnosis result'

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
X = prostate_data.drop('diagnosis_result', axis = 1)
y = prostate_data['diagnosis_result']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pd.DataFrame(model.coef_, X.columns, columns = ['Coef'])
# Out:
#                         Coef
# id                 -0.002780
# radius             -0.002320
# texture             0.017181
# perimeter           0.007729
# area               -0.000417
# smoothness         -3.259046
# compactness         5.843744
# symmetry           -1.180916
# fractal_dimension -28.016856

# %%
test_predictions = model.predict(X_test)
train_predictions = model.predict(X_train)

print('Test Metrics:')
print('R2', metrics.r2_score(y_test, test_predictions))
print('RMSE', metrics.mean_squared_error(y_test, test_predictions, squared = False))
print('MAE', metrics.mean_absolute_error(y_test, test_predictions))
print('\nTrain Metrics:')
print('R2', metrics.r2_score(y_train, train_predictions))
print('RMSE', metrics.mean_squared_error(y_train, train_predictions, squared = False))
print('MAE', metrics.mean_absolute_error(y_train, train_predictions))
# Out:
# Test Metrics:
# R2 0.505643543883258
# RMSE 0.3497902555659515
# MAE 0.2904848891583046
#
# Train Metrics:
# R2 0.48927329298912603
# RMSE 0.34354875920063244
# MAE 0.2848946194104494

# %% [markdown]
# After running the model several times, there is a lot of variance in R2 raning from 0.01 to 0.60. This indicates there is very low to moderate results that can be predicted by the dependent variables. Not quite the results I was looking for. However, RMSE and MAE have very low changes indicating some predictive value. I would like to try logistic regression analysis next.

# %%
prostate_data
# Out:
#      id  diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0     1                 1      23       12        151   954       0.143
# 1     2                 0       9       13        133  1326       0.143
# 2     3                 1      21       27        130  1203       0.125
# 3     4                 1      14       16         78   386       0.070
# 4     5                 1       9       19        135  1297       0.141
# ..  ...               ...     ...      ...        ...   ...         ...
# 95   96                 1      23       16        132  1264       0.091
# 96   97                 0      22       14         78   451       0.105
# 97   98                 0      19       27         62   295       0.102
# 98   99                 0      21       24         74   413       0.090
# 99  100                 1      16       27         94   643       0.098
#
#     compactness  symmetry  fractal_dimension
# 0         0.278     0.242              0.079
# 1         0.079     0.181              0.057
# 2         0.160     0.207              0.060
# 3         0.284     0.260              0.097
# 4         0.133     0.181              0.059
# ..          ...       ...                ...
# 95        0.131     0.210              0.056
# 96        0.071     0.190              0.066
# 97        0.053     0.135              0.069
# 98        0.075     0.162              0.066
# 99        0.114     0.188              0.064
#
# [100 rows x 10 columns]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial = PolynomialFeatures(degree = 3, include_bias = False)
X_train_pd = polynomial.fit_transform(X_train)
X_test_pd = polynomial.fit_transform(X_test)

# %%
regression = LinearRegression()
p_model = regression.fit(X_train_pd, y_train)

# %%
pd_test_predictions = p_model.predict(X_test_pd)
pd_train_predictions = p_model.predict(X_train_pd)

# %%
print('Test Metrics:')
print('R2', metrics.r2_score(y_test, pd_test_predictions))
print('RMSE', metrics.mean_squared_error(y_test, pd_test_predictions, squared = False))
print('MAE', metrics.mean_absolute_error(y_test, pd_test_predictions))
print('\nTrain Metrics:')
print('R2', metrics.r2_score(y_train, pd_train_predictions))
print('RMSE', metrics.mean_squared_error(y_train, pd_train_predictions, squared = False))
print('MAE', metrics.mean_absolute_error(y_train, pd_train_predictions))
# Out:
# Test Metrics:
# R2 -12.971764779678542
# RMSE 1.8595730109276267
# MAE 1.3904478112347953
#
# Train Metrics:
# R2 1.0
# RMSE 4.108444280005299e-10
# MAE 3.0068156853246817e-10

# %% [markdown]
# The polynomial model looks to have had successful tests on the training model but not so good on the test data. You can tell becasue of the high difference of the metrics. This model is suffering from overfitting
